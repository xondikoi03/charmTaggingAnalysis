# %% [markdown]
# # W+c Analysis (charm tagging)
#
# This analysis will focus on the selection of W+c Events for c-tagging study. The dataset used for this is: [W1JetsToLNu_TuneCP5_13TeV-madgraphMLM-pythia8](https://opendata.cern.ch/record/69544).

# %%
import ROOT as rt
import uproot as uprt
import mplhep as mh
import matplotlib.pyplot as plt
import awkward as ak
import numpy as np

# %%
# Defining the style for plots (CMS Style)
plt.style.use(mh.style.CMS)
plt.rcParams.update({
    "font.size": 17,
    "axes.labelsize": 17,
    "axes.titlesize": 17,
    "xtick.labelsize": 17,
    "ytick.labelsize": 17,
    "legend.fontsize": 17
})

# Defining the function for making histograms
def make_hist(data, bins, range, xlabel, ylabel, label, fname=None, logy=False):
    histo, edges = np.histogram(data, bins=bins, range=range)
    fig, ax = plt.subplots(1, 1, figsize=(8, 6))
    mh.histplot(histo, edges, histtype="step", label=label, ax=ax)
    mh.cms.label("Open Data", data=True, lumi=None, com=13, year=2016, loc=0)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend()
    if logy:
        ax.set_yscale("log")
    if fname:
        plt.savefig(fname)
    plt.show()

# %%
# Loading the ROOT file
NanoAODFile = uprt.open("../datasets/nano106X_on_mini106X_2017_mc_NANOAOD_W1Jets_to_LNu.root")
Events = NanoAODFile["Events"]

# %%
# We are interested in the RecoJets collections
RecoJet_keys = Events.keys(filter_name="Jet_*")
for RecoJets in Events.iterate(RecoJet_keys, step_size=Events.num_entries, library="ak"):
    break
# RecoJets

# %%
# Muons and electrons Collections
RecoMuon_keys = Events.keys(filter_name="Muon_*")
for RecoMuons in Events.iterate(RecoMuon_keys, step_size=Events.num_entries, library="ak"):
    break

RecoElectron_keys = Events.keys(filter_name="Electron_*")
for RecoElectrons in Events.iterate(RecoElectron_keys, step_size=Events.num_entries, library="ak"):
    break

# %%
# We are also interested in the GenJets collections
GenJet_keys = Events.keys(filter_name="GenJet_*")
for GenJets in Events.iterate(GenJet_keys, step_size=Events.num_entries, library="ak"):
    break
# GenJets

# MET collection
MET_keys = Events.keys(filter_name="MET_*")
for METs in Events.iterate(MET_keys, step_size=Events.num_entries, library="ak"):
    break

# %% [markdown]
# ## W $\rightarrow$ $\mu + \nu$ Event Selection:
#
# This part of the notebook selects all the events that pass the following cuts:
# - Jet $p_{T}$ > 30 GeV
# - Muon $p_{T}$ > 35 GeV
# - Muon $\eta$ > 2.4
# - Muon_pfRelIso04_all > 0.15
# - $M_{T}$ > 55 GeV
# - Events with two opposite signed muons with $p_{T}$ > 20 GeV

# %%
# Event Selection : W+c 
# Muons: HLT IsoMu24 OR HLT IsoTkMu24
# Rochester Corrections for Muons
# Muon Pt > 35 GeV, |eta| < 2.4
# I_comb = Sum(Pt(chargedhadrons)) + Et(neutralhadrons) + Et(photons) - Sum(pt(pileup))
# I_comb / pt(muon) < 0.15
# M_{T} > 55 GeV

# Jet Selection Cuts
passCuts = (RecoJets["Jet_pt"] > 30) & (abs(RecoJets["Jet_eta"]) < 2.4)
RecoJet_EvtSel = RecoJets[passCuts]

# This is the isolation cut (I_comb)
Muon_Pt_Cut = (RecoMuons["Muon_pt"] > 20)
Muon_pfIso_Cut = (abs(RecoMuons["Muon_pfRelIso04_all"] < 0.15))

# Missing Trasnverse Mass Cut
# M_t = sqrt(2 * pt_muon * MET_pt * (1 - cos(mu_phi - MET_phi)))
Muon_Mt = np.sqrt(2 * RecoMuons["Muon_pt"] * METs["MET_pt"] * (1 - np.cos(RecoMuons["Muon_phi"] - METs["MET_phi"])))
Muon_Mt_Cut = (Muon_Mt > 55)

# Tight Muons 
tightMuons_Selection = Muon_Pt_Cut & Muon_pfIso_Cut  
tightMuons = RecoMuons[tightMuons_Selection]

# Number of tight muons in the event
nTightMuons = (ak.num(tightMuons["Muon_pt"]))

# Selection cuts to reduce Drell-Yan contributions (OS muons)
nTightMuons_mask = (nTightMuons == 2) # Events that have two tight muons

# Sum of charges of the two tight muons should be zero (opposite sign)
tightMuon_OS_Cut = (ak.sum(tightMuons["Muon_charge"], axis=1) == 0)
OS_mask = nTightMuons_mask & tightMuon_OS_Cut

Muons_to_discard = ~OS_mask

# Final Selection Cuts
Final_Muons_Cuts = Muons_to_discard & Muon_Mt_Cut
Selected_Muons = tightMuons[Final_Muons_Cuts]

# Muons_to_discard

# Some plots to visualize the selected muons
Muon_pt = ak.to_numpy(ak.flatten(Selected_Muons["Muon_pt"]))

make_hist(
    nTightMuons,
    bins=50,
    range=(0, 5),
    xlabel="Number of Muons",
    ylabel="Events",
    label="Selected Tight Muons",
    fname="../Plots/nMuon_WcAnalysis.png",
    logy=False
)

make_hist(
    Muon_pt,
    bins=50,
    range=(0, 200),
    xlabel="Muon $p_{T}$ [GeV]",
    ylabel="Events",
    label="Selected Tight Muons",
    fname="../Plots/Muon_pt_WcAnalysis.png",
    logy=False
)

# %%
# Plot Leading Muon Sub-Leading Muon Pt Distribution 
# Also Add Data to see if we are mising any backgrounds

# Calculating number of selected muons after Wc event selection
nSelected_Muons = ak.num(Selected_Muons["Muon_pt"])

# Plotting Leading and Sub-Leading Muon Pt Distributions
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[76], line 8
#       5 nSelected_Muons = ak.num(Selected_Muons["Muon_pt"])
#       7 # Plotting Leading and Sub-Leading Muon Pt Distributions
# ----> 8 leadingMuon_pt = ak.to_numpy(ak.flatten(ak.firsts(ak.sort(Selected_Muons["Muon_pt"], axis=1, ascending=False))))
#       9 subleadingMuon_pt = ak.to_numpy(ak.flatten(ak.firsts(ak.sort(Selected_Muons["Muon_pt"], axis=1, ascending=False)[:, 1:2])))
#      11 make_hist(
#      12     leadingMuon_pt,
#      13     bins=50,
#    (...)
#      19     logy=False
#      20 )
#
# File ~/miniconda3/envs/aiml/lib/python3.12/site-packages/awkward/_dispatch.py:41, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      38 @wraps(func)
#      39 def dispatch(*args, **kwargs):
#      40     # NOTE: this decorator assumes that the operation is exposed under `ak.`
# ---> 41     with OperationErrorContext(name, args, kwargs):
#      42         gen_or_result = func(*args, **kwargs)
#      43         if isgenerator(gen_or_result):
#
# File ~/miniconda3/envs/aiml/lib/python3.12/site-packages/awkward/_errors.py:80, in ErrorContext.__exit__(self, exception_type, exception_value, traceback)
#      78     self._slate.__dict__.clear()
#      79     # Handle caught exception
# ---> 80     raise self.decorate_exception(exception_type, exception_value)
#      81 else:
#      82     # Step out of the way so that another ErrorContext can become primary.
#      83     if self.primary() is self:
#
# File ~/miniconda3/envs/aiml/lib/python3.12/site-packages/awkward/_dispatch.py:67, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      65 # Failed to find a custom overload, so resume the original function
#      66 try:
# ---> 67     next(gen_or_result)
#      68 except StopIteration as err:
#      69     return err.value
#
# File ~/miniconda3/envs/aiml/lib/python3.12/site-packages/awkward/operations/ak_flatten.py:178, in flatten(array, axis, highlevel, behavior, attrs)
#     175 yield (array,)
#     177 # Implementation
# --> 178 return _impl(array, axis, highlevel, behavior, attrs)
#
# File ~/miniconda3/envs/aiml/lib/python3.12/site-packages/awkward/operations/ak_flatten.py:255, in _impl(array, axis, highlevel, behavior, attrs)
#     253     out = apply(layout)
#     254 else:
# --> 255     out = ak._do.flatten(layout, axis)
#     257 wrapped_out = ctx.wrap(
#     258     out,
#     259     highlevel=highlevel,
#     260 )
#     262 # propagate named axis to output
#     263 #   if axis == None: use strategy "remove all" (see: awkward._namedaxis)
#
# File ~/miniconda3/envs/aiml/lib/python3.12/site-packages/awkward/_do.py:194, in flatten(layout, axis)
#     193 def flatten(layout: Content, axis: int = 1) -> Content:
# --> 194     offsets, flattened = layout._offsets_and_flattened(axis, 1)
#     195     return flattened
#
# File ~/miniconda3/envs/aiml/lib/python3.12/site-packages/awkward/contents/indexedoptionarray.py:609, in IndexedOptionArray._offsets_and_flattened(self, axis, depth)
#     606 numnull, nextcarry, outindex = self._nextcarry_outindex()
#     607 next = self._content._carry(nextcarry, False)
# --> 609 offsets, flattened = next._offsets_and_flattened(axis, depth)
#     611 if offsets.length is not unknown_length and offsets.length == 0:
#     612     return (
#     613         offsets,
#     614         ak.contents.IndexedOptionArray(
#     615             outindex, flattened, parameters=self._parameters
#     616         ),
#     617     )
#
# File ~/miniconda3/envs/aiml/lib/python3.12/site-packages/awkward/contents/numpyarray.py:465, in NumpyArray._offsets_and_flattened(self, axis, depth)
#     462     return self.to_RegularArray()._offsets_and_flattened(axis, depth)
#     464 else:
# --> 465     raise AxisError(f"axis={axis} exceeds the depth of this array ({depth})")
#
# AxisError: axis=1 exceeds the depth of this array (1)
#
# This error occurred while calling
#
#     ak.flatten(
#         <Array [None, None, None, ..., None, None, 25.6] type='1000 * ?float32'>
#     )
